# %%
# !pip install scikit-learn

# %%
# !pip install Scipy

# %%
# !pip install pillow

# %% [markdown]
# ### Scikit - Learn

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ML사용 프로세스

# %% [markdown]
# 1. 데이터 수집 -> 2. 점검 및 탐색 -> 3. 전처리 및 정제 -> 4. 모델링 및 훈련 -> 5. 테스트 데이터 -> 6. 평가 -> 7. 배포

# %%
from sklearn import neighbors, datasets, preprocessing
